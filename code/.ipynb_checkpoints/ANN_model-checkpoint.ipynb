# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import keras
from keras_preprocessing.sequence import pad_sequences
from keras.layers import Input, Dense, LSTM, Embedding, Conv1D, MaxPooling1D
from keras.layers import Dropout, Activation, Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
#import pandas as pd
#import numpy as np
np.random.seed(0)
from nltk import word_tokenize
from gensim.models import word2vec
import talos as ta
from keras.layers import Dropout
from talos.model.early_stopper import early_stopper
from talos.model.normalizers import lr_normalizer
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
#import seaborn as sns
#import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../csv/updated_target_merged_data.csv')
df.head()
# Out:
#          Date                                              Tweet Retweets  \
# 0  2011-12-01  Went to Iceland on Sat to ride bumper cars on ...      188
# 1  2011-12-01                  I made the volume on the Model S        78
# 2  2011-12-21  Got called randomly by Kanye West today and re...    1,682
# 3  2011-12-22  Model S options are out Performance in red and...      697
# 4  2011-12-22            Yum Even better than deep fried butter       165
#
#    Tweet Length  Polarity      pc_1      pc_2      pc_3      pc_4      pc_5  \
# 0           129  0.650000 -0.099076 -0.021082 -0.038139  0.000626  0.003329
# 1           125  0.000000 -0.114546 -0.035896 -0.126653  0.046923  0.045059
# 2           149 -0.500000 -0.025252 -0.022537 -0.027629  0.010788  0.008821
# 3           108 -0.083333 -0.010046 -0.037306 -0.072366  0.018803 -0.022556
# 4            69  0.250000 -0.075686  0.000404  0.068518 -0.045975 -0.004098
#
#    ...       pc_6545       pc_6546       pc_6547       pc_6548       pc_6549  \
# 0  ... -1.365654e-16 -1.207107e-17 -4.292488e-17 -1.012632e-16  2.789449e-17
# 1  ... -2.343465e-17  8.491505e-18 -1.573575e-18 -5.592959e-18 -1.693134e-17
# 2  ...  3.543562e-18  1.498232e-16 -3.937284e-17 -7.610591e-17  1.666605e-16
# 3  ...  7.314553e-18 -4.216318e-17 -4.045916e-17 -2.028475e-17  7.121853e-18
# 4  ... -3.601753e-17  5.117519e-17  3.655985e-17  3.055629e-17  8.163704e-18
#
#         pc_6550       pc_6551     Volume   Gap  Signal
# 0  2.114618e-18 -6.527066e-17  5151000.0  0.09     0.0
# 1 -1.008393e-17  2.044145e-17  5151000.0  0.09     0.0
# 2 -1.574024e-16 -1.107441e-16  8527500.0 -1.21    -1.0
# 3  1.292403e-17 -6.321830e-18  5047000.0  0.61     0.0
# 4  3.154859e-17  1.574211e-18  5047000.0  0.61     0.0
#
# [5 rows x 6559 columns]

# %%
# Scale Tweet Length
scaler = StandardScaler()
df_2 = df.drop(columns = ['Retweets'])
df_2[['Tweet Length']] = scaler.fit_transform(df[['Tweet Length']])
df_2.head()
# Out:
#          Date                                              Tweet  \
# 0  2011-12-01  Went to Iceland on Sat to ride bumper cars on ...
# 1  2011-12-01                  I made the volume on the Model S
# 2  2011-12-21  Got called randomly by Kanye West today and re...
# 3  2011-12-22  Model S options are out Performance in red and...
# 4  2011-12-22            Yum Even better than deep fried butter
#
#    Tweet Length  Polarity      pc_1      pc_2      pc_3      pc_4      pc_5  \
# 0      0.069559  0.650000 -0.099076 -0.021082 -0.038139  0.000626  0.003329
# 1      0.020779  0.000000 -0.114546 -0.035896 -0.126653  0.046923  0.045059
# 2      0.313460 -0.500000 -0.025252 -0.022537 -0.027629  0.010788  0.008821
# 3     -0.186538 -0.083333 -0.010046 -0.037306 -0.072366  0.018803 -0.022556
# 4     -0.662145  0.250000 -0.075686  0.000404  0.068518 -0.045975 -0.004098
#
#        pc_6  ...       pc_6545       pc_6546       pc_6547       pc_6548  \
# 0 -0.062547  ... -1.365654e-16 -1.207107e-17 -4.292488e-17 -1.012632e-16
# 1 -0.215881  ... -2.343465e-17  8.491505e-18 -1.573575e-18 -5.592959e-18
# 2 -0.007443  ...  3.543562e-18  1.498232e-16 -3.937284e-17 -7.610591e-17
# 3 -0.003767  ...  7.314553e-18 -4.216318e-17 -4.045916e-17 -2.028475e-17
# 4 -0.009915  ... -3.601753e-17  5.117519e-17  3.655985e-17  3.055629e-17
#
#         pc_6549       pc_6550       pc_6551     Volume   Gap  Signal
# 0  2.789449e-17  2.114618e-18 -6.527066e-17  5151000.0  0.09     0.0
# 1 -1.693134e-17 -1.008393e-17  2.044145e-17  5151000.0  0.09     0.0
# 2  1.666605e-16 -1.574024e-16 -1.107441e-16  8527500.0 -1.21    -1.0
# 3  7.121853e-18  1.292403e-17 -6.321830e-18  5047000.0  0.61     0.0
# 4  8.163704e-18  3.154859e-17  1.574211e-18  5047000.0  0.61     0.0
#
# [5 rows x 6558 columns]

# %%
target = df.Signal
y = pd.get_dummies(target).values

print(type(y))
y[:4]
# Out:
# <class 'numpy.ndarray'>
# array([[0, 1, 0],
#        [0, 1, 0],
#        [1, 0, 0],
#        [0, 1, 0]], dtype=uint8)

# %%
df_no_tweet = df_2.drop(['Date', 'Tweet', 'Volume', 'Gap', 'Signal'], axis=1)
df_no_tweet.head()
# Out:
#    Tweet Length  Polarity      pc_1      pc_2      pc_3      pc_4      pc_5  \
# 0      0.069559  0.650000 -0.099076 -0.021082 -0.038139  0.000626  0.003329
# 1      0.020779  0.000000 -0.114546 -0.035896 -0.126653  0.046923  0.045059
# 2      0.313460 -0.500000 -0.025252 -0.022537 -0.027629  0.010788  0.008821
# 3     -0.186538 -0.083333 -0.010046 -0.037306 -0.072366  0.018803 -0.022556
# 4     -0.662145  0.250000 -0.075686  0.000404  0.068518 -0.045975 -0.004098
#
#        pc_6      pc_7      pc_8  ...       pc_6542       pc_6543  \
# 0 -0.062547  0.042404  0.019719  ... -6.527914e-17  1.850555e-17
# 1 -0.215881  0.223829 -0.022574  ... -1.050660e-17 -7.721976e-18
# 2 -0.007443 -0.002720 -0.013345  ...  4.547889e-17  1.993619e-17
# 3 -0.003767  0.026777  0.008275  ... -1.731335e-18  3.387708e-18
# 4 -0.009915 -0.033327 -0.025617  ... -3.612426e-17 -1.639390e-17
#
#         pc_6544       pc_6545       pc_6546       pc_6547       pc_6548  \
# 0 -1.612357e-16 -1.365654e-16 -1.207107e-17 -4.292488e-17 -1.012632e-16
# 1  2.180771e-17 -2.343465e-17  8.491505e-18 -1.573575e-18 -5.592959e-18
# 2 -2.300245e-17  3.543562e-18  1.498232e-16 -3.937284e-17 -7.610591e-17
# 3 -3.267726e-17  7.314553e-18 -4.216318e-17 -4.045916e-17 -2.028475e-17
# 4 -1.340896e-17 -3.601753e-17  5.117519e-17  3.655985e-17  3.055629e-17
#
#         pc_6549       pc_6550       pc_6551
# 0  2.789449e-17  2.114618e-18 -6.527066e-17
# 1 -1.693134e-17 -1.008393e-17  2.044145e-17
# 2  1.666605e-16 -1.574024e-16 -1.107441e-16
# 3  7.121853e-18  1.292403e-17 -6.321830e-18
# 4  8.163704e-18  3.154859e-17  1.574211e-18
#
# [5 rows x 6553 columns]

# %%
# Features for the no_tweet ANN model
X = df_no_tweet.to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

classifier = Sequential()
classifier.add(Dense(units = 15, kernel_initializer='uniform', activation = 'tanh'))
classifier.add(Dense(units = 15, kernel_initializer='uniform', activation = 'tanh'))
classifier.add(Dense(units = 3, kernel_initializer='uniform', activation = 'softmax'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
c = classifier.fit(X_train, y_train, batch_size = 10, epochs = 4, validation_split=0.1)
# Out:
# Epoch 1/4
# 2022-07-21 19:53:39.360559: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 160889256 exceeds 10% of free system memory.
# 614/614 [==============================] - 2s 2ms/step - loss: 0.6429 - accuracy: 0.3516 - val_loss: 0.6375 - val_accuracy: 0.3284
# Epoch 2/4
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6350 - accuracy: 0.3545 - val_loss: 0.6402 - val_accuracy: 0.3284
# Epoch 3/4
# 614/614 [==============================] - 1s 1ms/step - loss: 0.6096 - accuracy: 0.4340 - val_loss: 0.6582 - val_accuracy: 0.3416
# Epoch 4/4
# 614/614 [==============================] - 1s 1ms/step - loss: 0.5247 - accuracy: 0.5559 - val_loss: 0.7065 - val_accuracy: 0.3446

# %%
score_no_tweet, acc_no_tweet = classifier.evaluate(X_test, y_test, verbose = 3, batch_size = 32)
print("score for the test data no tweet model: %.3f" % (score_no_tweet))
print("acc for the test data  no tweet model: %.7f" % (acc_no_tweet))

score_train_no_tweet, acc_train_no_tweet = classifier.evaluate(X_train, y_train, verbose = 3, batch_size = 32)
print("score for the training data no tweet model: %.3f" % (score_train_no_tweet))
print("acc for the training data no tweet model: %.7f" % (acc_train_no_tweet))
# Out:
# 2022-07-21 19:54:36.728102: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 44717672 exceeds 10% of free system memory.
# score for the test data no tweet model: 0.733
# acc for the test data  no tweet model: 0.3610786
# 2022-07-21 19:54:37.012964: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 178765840 exceeds 10% of free system memory.
# score for the training data no tweet model: 0.500
# acc for the training data no tweet model: 0.5799120

# %%
def plot_train_val(model, label):
    plt.plot(model.history[label]) 
    plt.plot(model.history['val_' + label])
    plt.title('model '+ label)
    plt.ylabel(label)
    plt.xlabel('epoch')
    plt.gca().legend(('train','val'))
    return plt.show()

# %%
plot_train_val(c, 'acc'), plot_train_val(c, 'loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 plot_train_val(c, 'acc'), plot_train_val(c, 'loss')
#
# Input In [16], in plot_train_val(model, label)
#       1 def plot_train_val(model, label):
# ----> 2     plt.plot(model.history[label])
#       3     plt.plot(model.history['val_' + label])
#       4     plt.title('model '+ label)
#
# NameError: name 'plt' is not defined
